# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X=dataset.iloc[:,1:-1].values
Y=dataset.iloc[:,-1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lr_model=LinearRegression()
lr_model.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
# first we will create additional features by raising the independent variable to different powers.
from sklearn.preprocessing import PolynomialFeatures
# we choose the degree and then try diff values to strike a balance between overfitting and fitting the data
poly_reg=PolynomialFeatures(degree=3)
# X can have any number of features
X_poly=poly_reg.fit_transform(X)
lr_model_2=LinearRegression()
lr_model_2.fit(X_poly,Y);

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X,Y,color='red')
plt.plot(X,lr_model.predict(X),color='blue')
plt.title('Truth or Bluff(Linear Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X,Y,color='red')
plt.plot(X,lr_model_2.predict(X_poly),color='blue')
plt.title('Truth or Bluff(Polynomial Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
plt.scatter(X,Y,color='red')
plt.plot(X,lr_model_2.predict(X_poly),color='blue')
plt.title('Truth or Bluff(Polynomial Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
lr_model.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
lr_model_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([133259.46969697])
